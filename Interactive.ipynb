# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('src')

# %%
import torch
import numpy as np
from torch import nn
from torch.utils.data import Dataset, DataLoader
from rich.progress import Progress, RenderableColumn, MofNCompleteColumn
from rich.live import Live
from rich.pretty import Pretty
from rich.table import Table
from collections import defaultdict
from torch.optim import Adam


torch.set_default_device('cuda')

# %%
from pathlib import Path

from data import simple_dense_data
from models import simple_dense_model
from workflow.train_workflow import train_network
from workflow.evaluation_workflow import evaluate_bit_depths
from workflow.visualization_workflow import visualize_bit_depth_results, write_train_history

train_loader, val_loader, test_loader = simple_dense_data.create_dataloaders()
net, crit, optim = simple_dense_model.create_model_context()

train_history = train_network(net, crit, optim, train_loader, val_loader, epochs=12)
results = evaluate_bit_depths(net, test_loader, crit, 2, 32)

visualize_bit_depth_results(results, Path('results / simple_dense / visualizations'))
write_train_history(train_history, Path('results / simple_dense / train_history'))
# Out:
# [05:52:22] Using torch device cuda                                                                      ]8;id=910588;file:///home/vramani1/projects/quantifind/src/utils.py\utils.py]8;;\:]8;id=758057;file:///home/vramani1/projects/quantifind/src/utils.py#11\11]8;;\
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from pathlib import Path

from data import mnist_data
from models import dense_mnist_model
from workflow.train_workflow import train_network
from workflow.evaluation_workflow import evaluate_bit_depths
from workflow.visualization_workflow import visualize_bit_depth_results, write_train_history

train_loader, val_loader, test_loader = mnist_data.create_dataloaders(batch_size=32)
net, crit, optim = dense_mnist_model.create_model_context()

train_history = train_network(net, crit, optim, train_loader, val_loader, epochs=12)
results = evaluate_bit_depths(net, test_loader, crit, 2, 32)

visualize_bit_depth_results(results, Path('results / dense_mnist / visualizations'))
write_train_history(train_history, Path('results / dense_mnist / train_history'))
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from pathlib import Path

from data import mnist_data
from models import conv_mnist_model
from workflow.train_workflow import train_network
from workflow.evaluation_workflow import evaluate_bit_depths
from workflow.visualization_workflow import visualize_bit_depth_results, write_train_history

train_loader, val_loader, test_loader = mnist_data.create_dataloaders(batch_size=32)
net, crit, optim = conv_mnist_model.create_model_context()

train_history = train_network(net, crit, optim, train_loader, val_loader, epochs=12)
results = evaluate_bit_depths(net, test_loader, crit, 2, 32)

visualize_bit_depth_results(results, Path('results / conv_mnist / visualizations'))
write_train_history(train_history, Path('results / conv_mnist / train_history'))
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from pathlib import Path

from data import language_names
from models import language_transformer_model
from workflow.train_workflow import train_network
from workflow.evaluation_workflow import evaluate_bit_depths
from workflow.visualization_workflow import visualize_bit_depth_results, write_train_history

train_loader, val_loader, test_loader = language_names.create_dataloaders(batch_size=32)
net, crit, optim = language_transformer_model.create_model_context()

train_history = train_network(net, crit, optim, train_loader, val_loader, epochs=12)
results = evaluate_bit_depths(net, test_loader, crit, 2, 32)

visualize_bit_depth_results(results, Path('results / language_model / visualizations'))
write_train_history(train_history, Path('results / language_model / train_history'))
# Out:
# Output()
# /scratch/zt1/project/niruroy-prj/user/vramani1/envs/quantifind/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 12
#       9 train_loader, val_loader, test_loader = language_names.create_dataloaders(batch_size=32)
#      10 net, crit, optim = language_transformer_model.create_model_context()
# ---> 12 train_history = train_network(net, crit, optim, train_loader, val_loader, epochs=12)
# ...
